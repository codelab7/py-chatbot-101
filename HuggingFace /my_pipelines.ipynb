# %%
#Sentiment analysis

from transformers import pipeline, logging
import warnings

# ૧. પાયથોનની સ્ટાન્ડર્ડ વોર્નિંગ્સ બંધ કરવા માટે
warnings.filterwarnings("ignore")

# ૨. હગિંગ ફેસ (Transformers) ના ઇન્ટરનલ મેસેજ અને પ્રોગ્રેસ બાર છુપાવવા માટે
logging.set_verbosity_error()

# ૩. અહીં મોડલનું નામ સ્પષ્ટ લખવાથી "No model was supplied" વાળી વોર્નિંગ દૂર થશે
classifier = pipeline("sentiment-analysis")


# ૧. પોઝિટિવ વાક્યનું ઉદાહરણ
text1 = "I absolutely love coding in Python! It is amazing."
result1 = classifier(text1)

print("=== Example 1===")
print(f"Sentences: '{text1}'")
print(f"Result : {result1[0]['label']}")
print(f"Score: {result1[0]['score']:.4f}\n")

# ૨. નેગેટિવ વાક્યનું ઉદાહરણ
text2 = "I am not coding person"
result2 = classifier(text2)

print("=== Example 2 ===")
print(f"Sentences: '{text2}'")
print(f"Result: {result2[0]['label']}")
print(f"Score: {result2[0]['score']:.4f}\n")
# Out:
# Loading weights: 100%|██████████████████████| 104/104 [00:00<00:00, 1904.40it/s]
# === Example 1===
# Sentences: 'I absolutely love coding in Python! It is amazing.'
# Result : POSITIVE
# Score: 0.9999
#
# === Example 2 ===
# Sentences: 'I am not coding person'
# Result: NEGATIVE
# Score: 0.9974

# %%
import os
# Hide Hugging Face token and symlink related warnings
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"
os.environ["TRANSFORMERS_NO_ADVISORY_WARNINGS"] = "true"

from transformers import pipeline, logging
import warnings

# 1. Disable standard Python warnings
warnings.filterwarnings("ignore")

# 2. Hide internal Hugging Face messages and progress bars
logging.set_verbosity_error()
# 3. Text Generation પાઇપલાઇન તૈયાર કરવી (આમાં ડિફોલ્ટ gpt2 મોડલ લોડ થશે)
generator = pipeline("text-generation")



# 1. Example 1: Starting a technology topic
text1 = "In the future, Artificial Intelligence will"
# max_length: આઉટપુટમાં ટોટલ કેટલા શબ્દો રાખવા છે તે સંખ્યા
result1 = generator(text1, max_length=40, num_return_sequences=1)

print("=== Example 1 ===")
print(f"Sentences: '{text1}'")
print(f"Result : {result1[0]['generated_text']}\n")

# # 2. Example 2: Starting a programming topic
# text2 = "Python is the best programming language because"
# result2 = generator(text2, max_length=40, num_return_sequences=1)

# print("=== Example 2 ===")
# print(f"Sentences: '{text2}'")
# print(f"Result: {result2[0]['generated_text']}\n")
# Out:
# Loading weights: 100%|██████████████████████| 326/326 [00:00<00:00, 1908.32it/s]
# === Example 1 ===
# Sentences: 'In the future, Artificial Intelligence will'
# Result : In the future, Artificial Intelligence will be able to assist people in their everyday lives. But how will we actually create such an AI? It would require an extremely powerful supercomputer and a vast amount of data. However, there are also concerns that AI might become uncontrollable if not properly designed.
#
# To address this challenge, we could create an AI that is more like a hybrid human-AI system. This way, the AI would have human-like capabilities, making it less likely to become uncontrollable. The AI could be designed to learn from humans, and in turn, help humans make decisions. It could also be designed to have a sense of empathy, allowing it to understand and respond to human emotions.
#
# For example, imagine an AI that is designed to help people with mental health issues. The AI could learn from therapists and psychologists, and provide personalized support to individuals. It could also be designed to detect early warning signs of mental health problems, and alert caregivers to intervene.
#
# Another potential use of AI is in education. An AI-powered tutoring system could be designed to learn from teachers and students, and provide personalized instruction. It could also be designed to adapt to individual learning styles, and provide additional support where needed.
#
# But what about the potential risks associated with AI? One concern is that AI could be used to manipulate

# %%
# સૌથી પહેલા ટર્મિનલમાં ઈન્સ્ટોલ કરો: pip install transformers torch

from transformers import pipeline

# ૧. સેન્ટિમેન્ટ એનાલિસિસ (Text Classification) માટે પાઈપલાઈન
classifier = pipeline("text-classification")
result = classifier("I am so happy to learn Hugging Face pipelines!")
print(result)
# Output: [{'label': 'POSITIVE', 'score': 0.9998}]

# ૨. ટેક્સ્ટ જનરેશન (Text Generation) માટે પાઈપલાઈન
generator = pipeline("text-generation") # તમે સ્પેસિફિક મોડલ પણ આપી શકો
story = generator("In a galaxy far away,", max_length=30)
print(story)
# Out:
# Loading weights: 100%|██████████████████████| 104/104 [00:00<00:00, 1688.32it/s]
# [{'label': 'POSITIVE', 'score': 0.9997437596321106}]
# Loading weights: 100%|██████████████████████| 326/326 [00:00<00:00, 1977.41it/s]
# [{'generated_text': 'In a galaxy far away, there are $n$ planets, and each planet has a unique orbit shape (circle, ellipse, parabola, or hyperbola). A space explorer can travel from one planet to another if they have different orbit shapes. The explorer starts on a planet with a circular orbit and can visit all other planets exactly once before returning to the starting planet. Find the maximum possible value of $n$ such that the explorer can complete this journey, which is known as a "planetary tour". Determine the complex number representing the explorer\'s position on the starting planet after completing the tour. Let this complex number be $z$. If the starting planet is located at the origin of a 2D coordinate system, express $z$ as a complex number in the form $a+bi$, where $a$ and $b$ are integers. Determine $a+b$.\n\nNote: In this problem, we are dealing with a specific constraint on the travel between planets, which requires that the explorer can only move between planets with different orbit shapes. This adds a new layer of complexity compared to the original problem, which only required that the explorer walked along the edges of a tetrahedron. The solution will likely involve graph theory and combinatorics. \n\nTo solve this problem'}]
