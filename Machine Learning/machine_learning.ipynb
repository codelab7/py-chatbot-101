# %% [markdown]
# **what is supervised learning? Give one real world example?**
#
#
# **Supervised** : Supervised learning is the type of the machine learning. this model learn from labeled data. labeled data means k input and output bane hoy che.
#                  **Simple meaning** : apde model ne input and outpt(labeled ) data apvi e data mathi model pattern sikhe and pachi prediction kare new data mate.
#
# **Example**
# **Spam detection** : apde janvanu che kayo email spam che and kayo email spam nathi. to aa model ma already data hoy means k ' free lottery','win jeckpot'. model train thayelu
#                      hoy k ava words ave to e spam detection hoy and 'meting','submisstion' ava words ave to a email spam ny hoy. means k supervised learning ma input and answer
#                      pn apelo hoy . input and output per thi patterns sikhe and pachi new data mate predict kare e supervised learning.

# %% [markdown]
# **what is supervised learning? Give one real world example?**
#
# **Unsupervised** : Unsupervised learning is type of the machine learning. this model learn from Unlabeled data. atle k right answer(output) apvama avtu nathi. model pote j
#                    data mathi pattern,group and structure mathi sodhe che.
#
# **Example**
# **Online Shopping (Amazon)** : Amazon pase lakho user na data hoy che. jem k su buy kare che. ketli var buy kare che.ketla rupees kharche che. aa data ma koi label nathi hoto
#                                k kon vadhare rich che kon poor che . k kayo user student che k kon young che . atle model pote customer ne group ma pade.
#                                **Group 1** : kon oocha rupees kharche che and small item vadhre buy kare che am ak group banave.
#                                **Group 2** : kon vadhare rupees kharche che and kon expensive product vadhre buy kare che am ak group banave.
#                                **Group 3** : kon kayarek j shopping kare che. and offer vakhate j product buy kare che am ak group banave che.
#                                aa goup joy ne amazon premium group ne expensive product batave. regular group ne offer vali product batave.
#                                and customer recommendation kare che k ene su buy karvu am.
#                         **Simple meaning** : Unsupervised learning ma labeled data hota nathi. model pote group padi ne kaya customer ne su batavu e nakhi kare che.

# %% [markdown]
# **what is different between feature and label?**
#
#
#  **Feature** : Input information used to make prediction. information given to model. jem k koi house price janvi hoy to ena feature like 'Size','Rooms'.
#                featurs data learn karva mate use thay che.
#
#  **label** : Output data hoy che. what model predict. answer the input. jem k house ni price e ans che. e ans input pase thi ave k size ketli che ena per thi model predict kare
#              che.

# %% [markdown]
# **what does it mean to train a model?**
#
# **Train Model** : train model is teach model using data and it can learn patterns and make predictions later.
#
# **Example** : koi data model ne apvi atle e data model learn kare che je. jem k koi houes ni price naki karvi hoy to houes na size per thi kari sakhavi. jo size moti to price
#              vadhre and size nani to prize ochi hoy sakhe. property ni website hoy che ena per old data hoy che ena per thi model train thay che. pachi predict kare che.

# %% [markdown]
# **Write your own simple analogy that explain machine learning in plain words?**
#
#
# **Machine learning** : machine learning means computers learn patterns from data and make predictions or decisions automatically.
#
# **Example**
# **youtubes recommend** : It collect data past behavior. youtube history mathi data ne collect kare che and and model samje che k user ne keva video game che. jo user re study na
#                         video vadhare joya hoy and ema vahare like, comment kare hoy to model train thay che k ava ava user ne video jova game che. ena per thi model next video
#                         jovanu recommention kare che. 90% high change che k user ne e video gamse . atle model hig chance vala cideo vadhare batave che.
# **Simple flow** :
#
# Your past activity
#         ↓
# ML finds patterns
#         ↓
# ML predicts what you may like
#         ↓
# Recommendations appear
