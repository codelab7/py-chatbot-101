# %%
from sentence_transformers import SentenceTransformer, util

# model load
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# Sentences
sentences = [
    "I like programming.",
    "I like coding.",
    "The weather is lovely today."
]

# Embedding 
embeddings = model.encode(sentences)

for i, sentence in enumerate(sentences):
    
    print("sentences: ",sentence)
    print("Shape: ",embeddings[i].shape)
    print("Sample Vector: ",embeddings[i][:5])

#cosine similarity
sim_1_2 = util.cos_sim(embeddings[0], embeddings[1])
sim_1_3 = util.cos_sim(embeddings[0], embeddings[2])
            
print("==Cosine similarity==")
print("Sentences 1 and 2: ",sim_1_2.item())
print("Sentences 1 and 3: ",sim_1_3.item())
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# sentences:  I like programming.
# Shape:  (384,)
# Sample Vector:  [ 0.00355113 -0.39507988 -0.03467039 -0.0030043  -0.24279548]
# sentences:  I like coding.
# Shape:  (384,)
# Sample Vector:  [-0.01162719 -0.46006107 -0.18488471 -0.03604228 -0.25380835]
# sentences:  The weather is lovely today.
# Shape:  (384,)
# Sample Vector:  [0.29033133 0.46465245 0.08998787 0.14782508 0.29542598]
# ==Cosine similarity==
# Sentences 1 and 2:  0.8979648351669312
# Sentences 1 and 3:  0.151178240776062
