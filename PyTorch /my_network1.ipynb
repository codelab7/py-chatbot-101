# %%
import torch
import torch.nn as nn

# ૧. ઇનપુટ ટેન્સર (ધારો કે ઘરની સાઈઝ ૨૦00 સ્ક્વેર ફીટ છે)
# AI ની ભાષામાં આને 'x' કહેવાય
house_size=2000
house_size = torch.tensor([[3000.0]]) 

# ૨. એક નાનું AI મોડલ (Linear Layer) બનાવવું
# આ મોડલ ૧ ઇનપુટ લેશે અને ૧ આઉટપુટ આપશે
model = nn.Linear(in_features=1, out_features=1)

# ૩. ફોરવર્ડ પાસ (Forward Pass) - માત્ર ઇનપુટ મોડલને આપો
with torch.no_grad(): # આપણે ટ્રેનિંગ નથી કરવી એટલે ગ્રેડિયન્ટ બંધ રાખ્યો છે
    predicted_price = model(house_size1)

# ૪. ફાઇનલ આઉટપુટ (Prediction) પ્રિન્ટ કરો
print("Predict Houseprice:", predicted_price.item())
# Out:
# Predict Houseprice: 999.12451171875
